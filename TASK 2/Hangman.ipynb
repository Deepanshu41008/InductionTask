# %%
import os                                                                                                                                                                                                                                                                                                                                
import random
import string
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import Dataset, DataLoader

##########################################
# 1. The Custom LSTM Model
##########################################                                                                                
class HangmanGuessModel(nn.Module):
    """
    A model that takes the masked word + guessed letters as input
    and outputs a distribution over the 26 possible letters (a-z).
    It uses an embedding + LSTM to capture sequential patterns
    resembling the word structure.
    """
    def __init__(self, embed_dim=64, hidden_dim=128, num_layers=1):
        super(HangmanGuessModel, self).__init__()
        # Our vocabulary is just the alphabet + underscore (_), plus a few possible spaces
        self.alphabet = list(string.ascii_lowercase)  # 26 letters
        self.extra_symbols = ['_', ' ']               # underscores and space for masked word
        self.vocab = self.alphabet + self.extra_symbols
        self.vocab_size = len(self.vocab)  # 28 in total (26 letters + '_' + ' ')
        
        # Embedding layer
        self.embedding = nn.Embedding(self.vocab_size, embed_dim)
        
        # LSTM to process the sequence of characters
        self.lstm = nn.LSTM(input_size=embed_dim, hidden_size=hidden_dim, num_layers=num_layers, batch_first=True)
        
        # Fully connected output layer
        self.fc = nn.Linear(hidden_dim, 26)  # 26 possible guesses (a-z)
        
    def forward(self, masked_word_str, guessed_letters,device):
        """
        masked_word_str: something like '_ _ a _ e'
        guessed_letters: a list of characters already guessed.
        
        Returns: A 1 x 26 tensor representing the probability
                 for each letter a-z.
        """
        device=next(self.parameters()).device
        # Convert masked_word_str and guessed_letters to indices from self.vocab
        raw_word = masked_word_str.split()
        
        input_indices = []
        for symbol in raw_word:
            if symbol in self.vocab:
                input_indices.append(self.vocab.index(symbol))
            else:
                # If something unexpected occurs, map it to underscore
                input_indices.append(self.vocab.index('_'))
        
        # Add guessed letters as well
        for letter in guessed_letters:
            if letter in self.alphabet:
                input_indices.append(self.vocab.index(letter))
        
        # Convert to tensor of shape [1, seq_len]
        input_tensor = torch.tensor(input_indices, dtype=torch.long).unsqueeze(0).to(device)  # batch of size 1
        # Embeddings
        embedded = self.embedding(input_tensor)  # shape: [1, seq_len, embed_dim]
        
        # LSTM
        output, (h, c) = self.lstm(embedded)  # output: [1, seq_len, hidden_dim]
        
        # Take the last hidden state from LSTM
        last_hidden = output[:, -1, :]  # shape: [1, hidden_dim]
        
        # Fully connected layer
        logits = self.fc(last_hidden)  # shape: [1, 26]
        
        # Return raw logits; caller can apply softmax or other logic
        return logits


##########################################
# 2. Improved Guess Function
##########################################

def improved_guess_fn(model, masked_word, guessed_letters):
    """
    Uses the trained model to predict the next letter.
    Applies a probability mask to exclude already-guessed letters.
    """
    model.eval()
    with torch.no_grad():
        logits = model(masked_word, guessed_letters,device)  # shape: [1, 26]
        probabilities = torch.softmax(logits, dim=1)  # shape: [1, 26]
    
    # Create a mask for already-guessed letters
    mask = torch.ones_like(probabilities)
    
    # Zero out the probabilities of letters we've already guessed
    for letter in guessed_letters:
        if letter in string.ascii_lowercase:
            idx = ord(letter) - 97
            mask[0, idx] = 0
    
    masked_prob = probabilities * mask
    predicted_index = torch.argmax(masked_prob, dim=1).item()
    
    return chr(predicted_index + 97)  # Convert back to 'a'-'z'


##########################################
# 3. Example of a Custom Dataset
##########################################
class HangmanDataset(Dataset):
    """
    Creates samples for training from a list of words.
    Each sample is artificially generated by partially revealing
    the word and specifying guessed letters. The label is the next correct letter.
    
    This is an oversimplification, but it often suffices to teach
    the model to guess missing letters.
    """
    def __init__(self, word_list, num_samples=10000, max_mask_frac=0.5):
        """
        word_list: list of possible words
        num_samples: how many samples to create
        max_mask_frac: fraction of letters we mask at max
        """
        self.word_list = word_list
        self.samples = []
        self.max_mask_frac = max_mask_frac
        
        self.alphabet = list(string.ascii_lowercase)
        self.extra_symbols = ['_', ' ']
        self.vocab = self.alphabet + self.extra_symbols
        self.vocab_map = {c: i for i, c in enumerate(self.vocab)}
        
        self._generate_samples(num_samples)
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        return self.samples[idx]
    
    def _generate_samples(self, num_samples):
        for _ in range(num_samples):
            word = random.choice(self.word_list)
            if len(word) == 0:
                continue
            
            # Mask some letters
            mask_count = random.randint(1, max(1, int(len(word) * self.max_mask_frac)))
            letters_to_keep = random.sample(range(len(word)), len(word) - mask_count)
            
            # Build masked word
            masked_chars = []
            for i, c in enumerate(word):
                if i in letters_to_keep:
                    masked_chars.append(c)
                else:
                    masked_chars.append('_')
            
            # Pick a target letter to guess
            masked_positions = [i for i, c in enumerate(masked_chars) if c == '_']
            target_pos = random.choice(masked_positions)
            target_letter = word[target_pos]
            
            # Generate guessed letters
            guessed_letters = []
            for i in letters_to_keep:
                if random.random() < 0.8:  # 80% chance to include it
                    guessed_letters.append(word[i])
            
            masked_word_str = ' '.join(masked_chars)  # e.g. "_ a _ _ t"
            label_idx = ord(target_letter) - 97
            
            self.samples.append((masked_word_str, guessed_letters, label_idx))


##########################################
# 4. Collate Function for DataLoader
##########################################
def hangman_collate_fn(batch):
    """
    Collates the batch into inputs and labels.
    """
    masked_words = []
    guessed_letters_batch = []
    labels = []
    
    for masked_word_str, guessed_list, label_idx in batch:
        masked_words.append(masked_word_str)
        guessed_letters_batch.append(guessed_list)
        labels.append(label_idx)
    
    labels = torch.tensor(labels, dtype=torch.long)
    return masked_words, guessed_letters_batch, labels


##########################################
# 5. The Training Loop
##########################################
# def train_hangman_rnn(
#     model, 
#     train_loader,
#     epochs=5,
#     lr=1e-3,
#     device=torch.device("cpu")
# ):                                                                                
    # """                                                            
    # Trains the HangmanGuessModel on the provided dataloader.
    # """
    # model.to(device)
    # optimizer = optim.Adam(model.parameters(), lr=lr)
    # criterion = nn.CrossEntropyLoss()
    
    # model.train()
    # for epoch in range(epochs):
    #     total_loss = 0.0
    #     for batch_idx, (masked_words, guessed_letters_batch, labels) in enumerate(train_loader):
    #         batch_losses = []
    #         for mw_str, g_letters, lbl in zip(masked_words, guessed_letters_batch, labels):
    #             logits = model(mw_str, g_letters)
    #             logits = logits.to(device)
    #             lbl = lbl.to(device)
    #             loss = criterion(logits, lbl.unsqueeze(0))  # shape: [1, 26], [1]
    #             batch_losses.append(loss)
            
    #         # Combine all sample losses in the batch
    #         batch_loss = torch.stack(batch_losses).mean()
            
    #         # Backprop
    #         optimizer.zero_grad()
    #         batch_loss.backward()
    #         optimizer.step()
            
    #         total_loss += batch_loss.item()
        
    #     print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_loader):.4f}")


##########################################
# 6. Putting It All Together in CynapticsHangman
##########################################
class CynapticsHangman():
    """
    Modified version where we plug in our improved model and guess function.
    """
    def __init__(self):
        self.guessed_letters = []
        self.train_dataset_location = r"C:\Users\gupta\Downloads\train.txt" 
        self.validation_dataset_location = r"C:\Users\gupta\Downloads\valid.txt"                    
        self.train_dictionary = self.build_dictionary(self.train_dataset_location)
        self.validation_dictionary = self.build_dictionary(self.validation_dataset_location)
        
        self.lives_remaining = 6
        # Our improved model is an LSTM-based approach
        self.model = HangmanGuessModel()
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
    
    # New return_status method definition
    def return_status(self, unmasked_word, masked_word, guessed_letter):
        """
        This method updates the lives remaining and the current masked word based on the guessed letter.
        It returns the updated status of the game: "ongoing", "success", or "failed".
        """
        # Check if the guessed letter is correct
        if guessed_letter in unmasked_word.replace(' ', ''):
            # Reveal all instances of guessed_letter in the masked word
            word_no_spaces = unmasked_word.replace(' ', '')
            new_mask_chars = []
            masked_chars = masked_word.split()
            
            # Reveal the guessed letter in the masked word
            for i, c in enumerate(word_no_spaces):
                if c == guessed_letter or masked_chars[i] != '_':
                    new_mask_chars.append(c)
                else:
                    new_mask_chars.append('_')
            masked_word = ' '.join(new_mask_chars)
            
            # Check if the word is completely revealed (i.e., no more '_')
            if '_' in masked_word:
                return "ongoing", self.lives_remaining, "Guess correct", masked_word
            else:
                return "success", self.lives_remaining, "Guess correct", masked_word
        else:
            # If guessed letter is incorrect, reduce lives
            self.lives_remaining -= 1
            if self.lives_remaining == 0:
                return "failed", self.lives_remaining, "Guess incorrect", masked_word
            else:
                return "ongoing", self.lives_remaining, "Guess incorrect", masked_word
    
    def guess(self, masked_word, lives_left):
        # Use the improved guess function with our trained model
        next_guess = improved_guess_fn(self.model, masked_word, self.guessed_letters)
        return next_guess
    
    # load/save weights
    def init_model(self, model_path):
        self.model = HangmanGuessModel()
        state_dict = torch.load(model_path, map_location=device if device else "cpu")
        self.model.load_state_dict( state_dict)
        self.model.eval()
        print(f"Model weights loaded from {model_path}")
    
    def save_model_weights(self, file_path):
        torch.save(self.model.state_dict(), file_path)
        print(f"Model weights saved to {file_path}")
    
    ######################################
    # The training routine
    ######################################
    def train(self, total_epochs=10, batch_size=32, train_samples=20000):
        print("Creating training dataset...")
        dataset = HangmanDataset(self.train_dictionary, num_samples=train_samples)
        loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=hangman_collate_fn)
        
        print("Training started...")
        train_hangman_rnn(
            model=self.model,
            train_loader=loader,
            epochs=total_epochs,
            lr=1e-3,
            device=device if device else torch.device("cpu")                    
        )
        
        # Save the weights
        weights_file = "hangman_model_weights_lstm.pth"
        self.save_model_weights(weights_file)
    
    ###################
    # Hangman Game
    ###################
    def start_game(self, game_id, verbose=True):
        self.guessed_letters = []
        self.guessed_letters.append(' ')
        word = random.choice(self.validation_dictionary)
        masked_word = '_' * len(word)
        masked_word = ' '.join(masked_word)
        word = ' '.join(word)
        self.lives_remaining = 6
        
        if verbose:
            print("New game started! Game ID: {0}\nLives: {1}\nWord: {2}\nMasked: {3}".format(game_id, self.lives_remaining, word, masked_word))
        
        self.max_tries = len(word) + 6
        
        while self.lives_remaining > 0 and self.max_tries > 0:
            guessed_letter = self.guess(masked_word, self.lives_remaining)
            self.guessed_letters.append(guessed_letter)
            
            if verbose:
                print(f"Guessing letter: {guessed_letter}")
            
            # Using the new return_status method
            status, self.lives_remaining, res, masked_word = self.return_status(word, masked_word, guessed_letter)
            
            if verbose:
                print("Status:", res, "Masked Word:", masked_word, "Lives:", self.lives_remaining)
            
            if status == "success":
                if verbose:
                    print(f"Game {game_id} success!\n")
                return True, 1
            elif status == "failed":
                if verbose:
                    print(f"Game {game_id} failed.\n")
                return False, 0
            
        # If we exit the loop without success or fail, we ran out of tries
        if verbose:
            print(f"Game {game_id} ended (out of tries).")
        return False, 0

# %%
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")                                                                                                    
  
  
  
  
  
    print("Using device:", device)
    
    # Initialize the CynapticsHangman game agent
    agent = CynapticsHangman()

# %%
   # Or, if the model is already trained, load the weights    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = r"C:\users\gupta\hangman_model_weights_lstm.pth"   
agent = CynapticsHangman()
agent.init_model(model_path)                    
# Start a game
total_games = 100
successes = 0
for game_id in range(1, total_games + 1):
    success, _ = agent.start_game(game_id, verbose=True)
    if success:
        successes += 1

    # Print the success rate
print(f"\nSuccess rate: {successes}/{total_games} games")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_43564\497457914.py:307: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device if device else "cpu")
# Model weights loaded from C:\users\gupta\hangman_model_weights_lstm.pth
# New game started! Game ID: 1
# Lives: 6
# Word: t h e r m o c l i n a l
# Masked: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ r _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: i
# Status: Guess correct Masked Word: t _ _ r _ _ _ _ i _ _ _ Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t _ _ r _ _ _ _ i n _ _ Lives: 6
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ _ r _ _ _ _ i n _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: t _ e r _ _ _ _ i n _ _ Lives: 5
# Guessing letter: m
# Status: Guess correct Masked Word: t _ e r m _ _ _ i n _ _ Lives: 5
# Guessing letter: o
# Status: Guess correct Masked Word: t _ e r m o _ _ i n _ _ Lives: 5
# Guessing letter: c
# Status: Guess correct Masked Word: t _ e r m o c _ i n _ _ Lives: 5
# Guessing letter: l
# Status: Guess correct Masked Word: t _ e r m o c l i n _ l Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: t _ e r m o c l i n a l Lives: 5
# Guessing letter: h
# Status: Guess correct Masked Word: t h e r m o c l i n a l Lives: 5
# Game 1 success!
#
# New game started! Game ID: 2
# Lives: 6
# Word: s u b s u l f i d e
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 3
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 2
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ _ _ e Lives: 2
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ e Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ e Lives: 0
# Game 2 failed.
#
# New game started! Game ID: 3
# Lives: 6
# Word: t h i g m o t a c t i c a l l y
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ t _ _ t _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ t _ _ t _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ _ _ _ _ t _ _ t _ _ _ _ _ _ Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t _ _ _ _ o t _ _ t _ _ _ _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ _ _ o t _ _ t _ _ _ _ _ _ Lives: 3
# Guessing letter: h
# Status: Guess correct Masked Word: t h _ _ _ o t _ _ t _ _ _ _ _ _ Lives: 3
# Guessing letter: a
# Status: Guess correct Masked Word: t h _ _ _ o t a _ t _ _ a _ _ _ Lives: 3
# Guessing letter: s
# Status: Guess incorrect Masked Word: t h _ _ _ o t a _ t _ _ a _ _ _ Lives: 2
# Guessing letter: i
# Status: Guess correct Masked Word: t h i _ _ o t a _ t i _ a _ _ _ Lives: 2
# Guessing letter: c
# Status: Guess correct Masked Word: t h i _ _ o t a c t i c a _ _ _ Lives: 2
# Guessing letter: l
# Status: Guess correct Masked Word: t h i _ _ o t a c t i c a l l _ Lives: 2
# Guessing letter: u
# Status: Guess incorrect Masked Word: t h i _ _ o t a c t i c a l l _ Lives: 1
# Guessing letter: d
# Status: Guess incorrect Masked Word: t h i _ _ o t a c t i c a l l _ Lives: 0
# Game 3 failed.
#
# New game started! Game ID: 4
# Lives: 6
# Word: s t u d l e y
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: s t _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: s t _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: s t _ _ _ e _ Lives: 5
# Guessing letter: l
# Status: Guess correct Masked Word: s t _ _ l e _ Lives: 5
# Guessing letter: i
# Status: Guess incorrect Masked Word: s t _ _ l e _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: s t _ _ l e _ Lives: 3
# Guessing letter: a
# Status: Guess incorrect Masked Word: s t _ _ l e _ Lives: 2
# Guessing letter: u
# Status: Guess correct Masked Word: s t u _ l e _ Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: s t u _ l e _ Lives: 1
# Guessing letter: d
# Status: Guess correct Masked Word: s t u d l e _ Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: s t u d l e _ Lives: 0
# Game 4 failed.
#
# New game started! Game ID: 5
# Lives: 6
# Word: s t o n y h e a r t e d n e s s
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ _ _ t _ _ _ _ _ _ Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: _ t _ _ _ _ _ a _ t _ _ _ _ _ _ Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: _ t _ n _ _ _ a _ t _ _ n _ _ _ Lives: 6
# Guessing letter: o
# Status: Guess correct Masked Word: _ t o n _ _ _ a _ t _ _ n _ _ _ Lives: 6
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ t o n _ _ _ a _ t _ _ n _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess correct Masked Word: s t o n _ _ _ a _ t _ _ n _ s s Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: s t o n _ _ e a _ t e _ n e s s Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: s t o n _ _ e a _ t e _ n e s s Lives: 4
# Guessing letter: p
# Status: Guess incorrect Masked Word: s t o n _ _ e a _ t e _ n e s s Lives: 3
# Guessing letter: l
# Status: Guess incorrect Masked Word: s t o n _ _ e a _ t e _ n e s s Lives: 2
# Guessing letter: h
# Status: Guess correct Masked Word: s t o n _ h e a _ t e _ n e s s Lives: 2
# Guessing letter: u
# Status: Guess incorrect Masked Word: s t o n _ h e a _ t e _ n e s s Lives: 1
# Guessing letter: d
# Status: Guess correct Masked Word: s t o n _ h e a _ t e d n e s s Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: s t o n _ h e a _ t e d n e s s Lives: 0
# Game 5 failed.
#
# New game started! Game ID: 6
# Lives: 6
# Word: t a w p i
# Masked: _ _ _ _ _
# Guessing letter: a
# Status: Guess correct Masked Word: _ a _ _ _ Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ a _ _ _ Lives: 5
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ a _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ a _ _ _ Lives: 3
# Guessing letter: d
# Status: Guess incorrect Masked Word: _ a _ _ _ Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ a _ _ _ Lives: 1
# Guessing letter: p
# Status: Guess correct Masked Word: _ a _ p _ Lives: 1
# Guessing letter: s
# Status: Guess incorrect Masked Word: _ a _ p _ Lives: 0
# Game 6 failed.
#
# New game started! Game ID: 7
# Lives: 6
# Word: s u b t e r r a q u e o u s
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ _ _ t _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ t _ _ _ a _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: _ _ _ t _ r r a _ _ _ _ _ _ Lives: 6
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ t _ r r a _ _ _ _ _ _ Lives: 5
# Guessing letter: h
# Status: Guess incorrect Masked Word: _ _ _ t _ r r a _ _ _ _ _ _ Lives: 4
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ t e r r a _ _ e _ _ _ Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: _ _ _ t e r r a _ _ e o _ _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ t e r r a _ _ e o _ _ Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ t e r r a _ _ e o _ _ Lives: 2
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ _ t e r r a _ _ e o _ _ Lives: 1
# Guessing letter: s
# Status: Guess correct Masked Word: s _ _ t e r r a _ _ e o _ s Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: s _ _ t e r r a _ _ e o _ s Lives: 0
# Game 7 failed.
#
# New game started! Game ID: 8
# Lives: 6
# Word: s p o u s e l e s s
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 3
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 2
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ _ e _ e _ _ Lives: 2
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ _ e _ e _ _ Lives: 1
# Guessing letter: p
# Status: Guess correct Masked Word: _ p _ _ _ e _ e _ _ Lives: 1
# Guessing letter: o
# Status: Guess correct Masked Word: _ p o _ _ e _ e _ _ Lives: 1
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ p o _ _ e _ e _ _ Lives: 0
# Game 8 failed.
#
# New game started! Game ID: 9
# Lives: 6
# Word: t o y m a k i n g
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t o _ _ _ _ _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess correct Masked Word: t o _ _ _ _ _ n _ Lives: 4
# Guessing letter: c
# Status: Guess incorrect Masked Word: t o _ _ _ _ _ n _ Lives: 3
# Guessing letter: m
# Status: Guess correct Masked Word: t o _ m _ _ _ n _ Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: t o _ m _ _ i n _ Lives: 3
# Guessing letter: s
# Status: Guess incorrect Masked Word: t o _ m _ _ i n _ Lives: 2
# Guessing letter: d
# Status: Guess incorrect Masked Word: t o _ m _ _ i n _ Lives: 1
# Guessing letter: a
# Status: Guess correct Masked Word: t o _ m a _ i n _ Lives: 1
# Guessing letter: u
# Status: Guess incorrect Masked Word: t o _ m a _ i n _ Lives: 0
# Game 9 failed.
#
# New game started! Game ID: 10
# Lives: 6
# Word: t a r k h a n
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ r _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ r _ _ _ _ Lives: 5
# Guessing letter: o
# Status: Guess incorrect Masked Word: t _ r _ _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess correct Masked Word: t _ r _ _ _ n Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: t _ r _ _ _ n Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ r _ _ _ n Lives: 2
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ r _ _ _ n Lives: 1
# Guessing letter: u
# Status: Guess incorrect Masked Word: t _ r _ _ _ n Lives: 0
# Game 10 failed.
#
# New game started! Game ID: 11
# Lives: 6
# Word: s u c c i n i c
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ Lives: 3
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ _ _ n _ _ Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ _ _ i n i _ Lives: 3
# Guessing letter: c
# Status: Guess correct Masked Word: _ _ c c i n i c Lives: 3
# Guessing letter: s
# Status: Guess correct Masked Word: s _ c c i n i c Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: s _ c c i n i c Lives: 2
# Guessing letter: e
# Status: Guess incorrect Masked Word: s _ c c i n i c Lives: 1
# Guessing letter: u
# Status: Guess correct Masked Word: s u c c i n i c Lives: 1
# Game 11 success!
#
# New game started! Game ID: 12
# Lives: 6
# Word: s u p e r d e m a n d
# Masked: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ _ a _ _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ _ a n _ Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ a n _ Lives: 4
# Guessing letter: m
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ m a n _ Lives: 4
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ m a n _ Lives: 3
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ m a n _ Lives: 2
# Guessing letter: p
# Status: Guess correct Masked Word: _ _ p _ _ _ _ m a n _ Lives: 2
# Guessing letter: s
# Status: Guess correct Masked Word: s _ p _ _ _ _ m a n _ Lives: 2
# Guessing letter: l
# Status: Guess incorrect Masked Word: s _ p _ _ _ _ m a n _ Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: s _ p _ _ _ _ m a n _ Lives: 0
# Game 12 failed.
#
# New game started! Game ID: 13
# Lives: 6
# Word: t e m p o r a n e o u s n e s s
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ _ _ r _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t e _ _ _ r _ _ e _ _ _ _ e _ _ Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t e _ _ _ r _ n e _ _ _ n e _ _ Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: t e _ _ _ r a n e _ _ _ n e _ _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: t e _ _ _ r a n e _ _ s n e s s Lives: 6
# Guessing letter: i
# Status: Guess incorrect Masked Word: t e _ _ _ r a n e _ _ s n e s s Lives: 5
# Guessing letter: p
# Status: Guess correct Masked Word: t e _ p _ r a n e _ _ s n e s s Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: t e _ p _ r a n e _ _ s n e s s Lives: 4
# Guessing letter: m
# Status: Guess correct Masked Word: t e m p _ r a n e _ _ s n e s s Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t e m p o r a n e o _ s n e s s Lives: 4
# Guessing letter: u
# Status: Guess correct Masked Word: t e m p o r a n e o u s n e s s Lives: 4
# Game 13 success!
#
# New game started! Game ID: 14
# Lives: 6
# Word: s t r o n g h e a d e d n e s s
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: s t _ _ _ _ _ _ _ _ _ _ _ _ s s Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: s t r _ _ _ _ _ _ _ _ _ _ _ s s Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: s t r _ _ _ _ e _ _ e _ _ e s s Lives: 6
# Guessing letter: c
# Status: Guess incorrect Masked Word: s t r _ _ _ _ e _ _ e _ _ e s s Lives: 5
# Guessing letter: p
# Status: Guess incorrect Masked Word: s t r _ _ _ _ e _ _ e _ _ e s s Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: s t r _ _ _ _ e _ _ e _ _ e s s Lives: 3
# Guessing letter: n
# Status: Guess correct Masked Word: s t r _ n _ _ e _ _ e _ n e s s Lives: 3
# Guessing letter: d
# Status: Guess correct Masked Word: s t r _ n _ _ e _ d e d n e s s Lives: 3
# Guessing letter: a
# Status: Guess correct Masked Word: s t r _ n _ _ e a d e d n e s s Lives: 3
# Guessing letter: o
# Status: Guess correct Masked Word: s t r o n _ _ e a d e d n e s s Lives: 3
# Guessing letter: l
# Status: Guess incorrect Masked Word: s t r o n _ _ e a d e d n e s s Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: s t r o n _ _ e a d e d n e s s Lives: 1
# Guessing letter: u
# Status: Guess incorrect Masked Word: s t r o n _ _ e a d e d n e s s Lives: 0
# Game 14 failed.
#
# New game started! Game ID: 15
# Lives: 6
# Word: s p h a g n a c e a e
# Masked: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ a _ _ a _ _ a _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ a _ n a _ _ a _ Lives: 5
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ _ a _ n a _ _ a _ Lives: 4
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ a _ n a _ e a e Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ a _ n a _ e a e Lives: 3
# Guessing letter: p
# Status: Guess correct Masked Word: _ p _ a _ n a _ e a e Lives: 3
# Guessing letter: c
# Status: Guess correct Masked Word: _ p _ a _ n a c e a e Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ p _ a _ n a c e a e Lives: 2
# Guessing letter: l
# Status: Guess incorrect Masked Word: _ p _ a _ n a c e a e Lives: 1
# Guessing letter: h
# Status: Guess correct Masked Word: _ p h a _ n a c e a e Lives: 1
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ p h a _ n a c e a e Lives: 0
# Game 15 failed.
#
# New game started! Game ID: 16
# Lives: 6
# Word: t o u t e r
# Masked: _ _ _ _ _ _
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ e _ Lives: 3
# Guessing letter: r
# Status: Guess correct Masked Word: _ _ _ _ e r Lives: 3
# Guessing letter: d
# Status: Guess incorrect Masked Word: _ _ _ _ e r Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ _ e r Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ _ _ e r Lives: 0
# Game 16 failed.
#
# New game started! Game ID: 17
# Lives: 6
# Word: s p r a c k n e s s
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ a _ _ _ _ _ _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ a _ _ n _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ a _ _ n _ _ _ Lives: 4
# Guessing letter: l
# Status: Guess incorrect Masked Word: _ _ _ a _ _ n _ _ _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ a _ _ n e _ _ Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ _ a _ _ n e _ _ Lives: 2
# Guessing letter: p
# Status: Guess correct Masked Word: _ p _ a _ _ n e _ _ Lives: 2
# Guessing letter: c
# Status: Guess correct Masked Word: _ p _ a c _ n e _ _ Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ p _ a c _ n e _ _ Lives: 1
# Guessing letter: r
# Status: Guess correct Masked Word: _ p r a c _ n e _ _ Lives: 1
# Guessing letter: s
# Status: Guess correct Masked Word: s p r a c _ n e s s Lives: 1
# Guessing letter: y
# Status: Guess incorrect Masked Word: s p r a c _ n e s s Lives: 0
# Game 17 failed.
#
# New game started! Game ID: 18
# Lives: 6
# Word: t h e o r e m a t i c a l
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ t _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ _ r _ _ _ t _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t _ e _ r e _ _ t _ _ _ _ Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ e _ r e _ _ t _ _ _ _ Lives: 5
# Guessing letter: h
# Status: Guess correct Masked Word: t h e _ r e _ _ t _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: t h e _ r e _ a t _ _ a _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: t h e _ r e _ a t _ _ a _ Lives: 4
# Guessing letter: c
# Status: Guess correct Masked Word: t h e _ r e _ a t _ c a _ Lives: 4
# Guessing letter: l
# Status: Guess correct Masked Word: t h e _ r e _ a t _ c a l Lives: 4
# Guessing letter: i
# Status: Guess correct Masked Word: t h e _ r e _ a t i c a l Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t h e o r e _ a t i c a l Lives: 4
# Guessing letter: m
# Status: Guess correct Masked Word: t h e o r e m a t i c a l Lives: 4
# Game 18 success!
#
# New game started! Game ID: 19
# Lives: 6
# Word: s t o m o x y s
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: s t _ _ _ _ _ s Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: s t _ _ _ _ _ s Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: s t _ _ _ _ _ s Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: s t o _ o _ _ s Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: s t o _ o _ _ s Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: s t o _ o _ _ s Lives: 2
# Guessing letter: i
# Status: Guess incorrect Masked Word: s t o _ o _ _ s Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: s t o _ o _ _ s Lives: 0
# Game 19 failed.
#
# New game started! Game ID: 20
# Lives: 6
# Word: s p h a e r i a c e a e
# Masked: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ a _ _ _ a _ _ a _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ a _ _ _ a _ _ a _ Lives: 4
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ _ a _ _ _ a _ _ a _ Lives: 3
# Guessing letter: r
# Status: Guess correct Masked Word: _ _ _ a _ r _ a _ _ a _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ a e r _ a _ e a e Lives: 3
# Guessing letter: c
# Status: Guess correct Masked Word: _ _ _ a e r _ a c e a e Lives: 3
# Guessing letter: p
# Status: Guess correct Masked Word: _ p _ a e r _ a c e a e Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: _ p _ a e r i a c e a e Lives: 3
# Guessing letter: h
# Status: Guess correct Masked Word: _ p h a e r i a c e a e Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ p h a e r i a c e a e Lives: 2
# Guessing letter: s
# Status: Guess correct Masked Word: s p h a e r i a c e a e Lives: 2
# Game 20 success!
#
# New game started! Game ID: 21
# Lives: 6
# Word: t o o t i n g
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ t _ _ _ Lives: 6
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ _ t _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: t _ _ t _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ t _ _ _ Lives: 3
# Guessing letter: o
# Status: Guess correct Masked Word: t o o t _ _ _ Lives: 3
# Guessing letter: l
# Status: Guess incorrect Masked Word: t o o t _ _ _ Lives: 2
# Guessing letter: h
# Status: Guess incorrect Masked Word: t o o t _ _ _ Lives: 1
# Guessing letter: i
# Status: Guess correct Masked Word: t o o t i _ _ Lives: 1
# Guessing letter: n
# Status: Guess correct Masked Word: t o o t i n _ Lives: 1
# Guessing letter: e
# Status: Guess incorrect Masked Word: t o o t i n _ Lives: 0
# Game 21 failed.
#
# New game started! Game ID: 22
# Lives: 6
# Word: t r o u n c e d
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t r _ _ _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t r _ _ _ _ e _ Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t r _ _ n _ e _ Lives: 6
# Guessing letter: c
# Status: Guess correct Masked Word: t r _ _ n c e _ Lives: 6
# Guessing letter: a
# Status: Guess incorrect Masked Word: t r _ _ n c e _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: t r _ _ n c e _ Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: t r _ _ n c e _ Lives: 3
# Guessing letter: o
# Status: Guess correct Masked Word: t r o _ n c e _ Lives: 3
# Guessing letter: u
# Status: Guess correct Masked Word: t r o u n c e _ Lives: 3
# Guessing letter: d
# Status: Guess correct Masked Word: t r o u n c e d Lives: 3
# Game 22 success!
#
# New game started! Game ID: 23
# Lives: 6
# Word: t o m p k i n s v i l l e
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ _ _ e Lives: 5
# Guessing letter: o
# Status: Guess correct Masked Word: t o _ _ _ _ _ _ _ _ _ _ e Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: t o _ _ _ _ n _ _ _ _ _ e Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: t o _ _ _ _ n _ _ _ _ _ e Lives: 4
# Guessing letter: a
# Status: Guess incorrect Masked Word: t o _ _ _ _ n _ _ _ _ _ e Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: t o _ _ _ i n _ _ i _ _ e Lives: 3
# Guessing letter: p
# Status: Guess correct Masked Word: t o _ p _ i n _ _ i _ _ e Lives: 3
# Guessing letter: s
# Status: Guess correct Masked Word: t o _ p _ i n s _ i _ _ e Lives: 3
# Guessing letter: m
# Status: Guess correct Masked Word: t o m p _ i n s _ i _ _ e Lives: 3
# Guessing letter: l
# Status: Guess correct Masked Word: t o m p _ i n s _ i l l e Lives: 3
# Guessing letter: h
# Status: Guess incorrect Masked Word: t o m p _ i n s _ i l l e Lives: 2
# Guessing letter: d
# Status: Guess incorrect Masked Word: t o m p _ i n s _ i l l e Lives: 1
# Guessing letter: u
# Status: Guess incorrect Masked Word: t o m p _ i n s _ i l l e Lives: 0
# Game 23 failed.
#
# New game started! Game ID: 24
# Lives: 6
# Word: t y p o l o g y
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t _ _ o _ o _ _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ o _ o _ _ Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ _ o _ o _ _ Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: t _ _ o _ o _ _ Lives: 1
# Guessing letter: i
# Status: Guess incorrect Masked Word: t _ _ o _ o _ _ Lives: 0
# Game 24 failed.
#
# New game started! Game ID: 25
# Lives: 6
# Word: t e k l a
# Masked: _ _ _ _ _
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ _ a Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ _ a Lives: 5
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ a Lives: 4
# Guessing letter: l
# Status: Guess correct Masked Word: _ _ _ l a Lives: 4
# Guessing letter: b
# Status: Guess incorrect Masked Word: _ _ _ l a Lives: 3
# Guessing letter: u
# Status: Guess incorrect Masked Word: _ _ _ l a Lives: 2
# Guessing letter: e
# Status: Guess correct Masked Word: _ e _ l a Lives: 2
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ e _ l a Lives: 1
# Guessing letter: d
# Status: Guess incorrect Masked Word: _ e _ l a Lives: 0
# Game 25 failed.
#
# New game started! Game ID: 26
# Lives: 6
# Word: u g l y c o n d i t i o n e d
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ _ _ t _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ t _ _ _ _ _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ _ _ _ n _ _ t _ _ n _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ _ _ n _ _ t _ _ n e _ Lives: 5
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ n _ _ t _ _ n e _ Lives: 4
# Guessing letter: c
# Status: Guess correct Masked Word: _ _ _ _ c _ n _ _ t _ _ n e _ Lives: 4
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ c _ n _ _ t _ _ n e _ Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ _ _ c _ n _ i t i _ n e _ Lives: 3
# Guessing letter: s
# Status: Guess incorrect Masked Word: _ _ _ _ c _ n _ i t i _ n e _ Lives: 2
# Guessing letter: o
# Status: Guess correct Masked Word: _ _ _ _ c o n _ i t i o n e _ Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ _ _ c o n _ i t i o n e _ Lives: 1
# Guessing letter: u
# Status: Guess correct Masked Word: u _ _ _ c o n _ i t i o n e _ Lives: 1
# Guessing letter: l
# Status: Guess correct Masked Word: u _ l _ c o n _ i t i o n e _ Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: u _ l _ c o n _ i t i o n e _ Lives: 0
# Game 26 failed.
#
# New game started! Game ID: 27
# Lives: 6
# Word: s t i f l e r
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: s t _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: s t _ _ _ _ r Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: s t _ _ _ e r Lives: 6
# Guessing letter: i
# Status: Guess correct Masked Word: s t i _ _ e r Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: s t i _ _ e r Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: s t i _ _ e r Lives: 4
# Guessing letter: m
# Status: Guess incorrect Masked Word: s t i _ _ e r Lives: 3
# Guessing letter: p
# Status: Guess incorrect Masked Word: s t i _ _ e r Lives: 2
# Guessing letter: d
# Status: Guess incorrect Masked Word: s t i _ _ e r Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: s t i _ _ e r Lives: 0
# Game 27 failed.
#
# New game started! Game ID: 28
# Lives: 6
# Word: t u t t i f r u t t i
# Masked: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ t t _ _ _ _ t t _ Lives: 6
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ t t _ _ _ _ t t _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ t t _ _ _ _ t t _ Lives: 4
# Guessing letter: a
# Status: Guess incorrect Masked Word: t _ t t _ _ _ _ t t _ Lives: 3
# Guessing letter: r
# Status: Guess correct Masked Word: t _ t t _ _ r _ t t _ Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: t _ t t _ _ r _ t t _ Lives: 2
# Guessing letter: i
# Status: Guess correct Masked Word: t _ t t i _ r _ t t i Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ t t i _ r _ t t i Lives: 1
# Guessing letter: l
# Status: Guess incorrect Masked Word: t _ t t i _ r _ t t i Lives: 0
# Game 28 failed.
#
# New game started! Game ID: 29
# Lives: 6
# Word: s t o l i d
# Masked: _ _ _ _ _ _
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess correct Masked Word: s _ _ _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: s _ _ _ i _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: s _ _ _ i _ Lives: 4
# Guessing letter: e
# Status: Guess incorrect Masked Word: s _ _ _ i _ Lives: 3
# Guessing letter: m
# Status: Guess incorrect Masked Word: s _ _ _ i _ Lives: 2
# Guessing letter: o
# Status: Guess correct Masked Word: s _ o _ i _ Lives: 2
# Guessing letter: l
# Status: Guess correct Masked Word: s _ o l i _ Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: s _ o l i _ Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: s _ o l i _ Lives: 0
# Game 29 failed.
#
# New game started! Game ID: 30
# Lives: 6
# Word: s u i v e z
# Masked: _ _ _ _ _ _
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess correct Masked Word: s _ _ _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: s _ i _ _ _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: s _ i _ _ _ Lives: 4
# Guessing letter: m
# Status: Guess incorrect Masked Word: s _ i _ _ _ Lives: 3
# Guessing letter: t
# Status: Guess incorrect Masked Word: s _ i _ _ _ Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: s _ i _ _ _ Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: s _ i _ _ _ Lives: 0
# Game 30 failed.
#
# New game started! Game ID: 31
# Lives: 6
# Word: t h a l l o c h l o r e
# Masked: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ r _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ r e Lives: 6
# Guessing letter: o
# Status: Guess correct Masked Word: t _ _ _ _ o _ _ _ o r e Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ _ _ o _ _ _ o r e Lives: 5
# Guessing letter: c
# Status: Guess correct Masked Word: t _ _ _ _ o c _ _ o r e Lives: 5
# Guessing letter: p
# Status: Guess incorrect Masked Word: t _ _ _ _ o c _ _ o r e Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: t _ _ _ _ o c _ _ o r e Lives: 3
# Guessing letter: h
# Status: Guess correct Masked Word: t h _ _ _ o c h _ o r e Lives: 3
# Guessing letter: u
# Status: Guess incorrect Masked Word: t h _ _ _ o c h _ o r e Lives: 2
# Guessing letter: s
# Status: Guess incorrect Masked Word: t h _ _ _ o c h _ o r e Lives: 1
# Guessing letter: a
# Status: Guess correct Masked Word: t h a _ _ o c h _ o r e Lives: 1
# Guessing letter: l
# Status: Guess correct Masked Word: t h a l l o c h l o r e Lives: 1
# Game 31 success!
#
# New game started! Game ID: 32
# Lives: 6
# Word: s w g
# Masked: _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ Lives: 3
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ Lives: 2
# Guessing letter: e
# Status: Guess incorrect Masked Word: _ _ _ Lives: 1
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ _ Lives: 0
# Game 32 failed.
#
# New game started! Game ID: 33
# Lives: 6
# Word: t z a r i t z a s
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ t _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ r _ t _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ _ r _ t _ _ _ Lives: 5
# Guessing letter: o
# Status: Guess incorrect Masked Word: t _ _ r _ t _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ r _ t _ _ _ Lives: 3
# Guessing letter: s
# Status: Guess correct Masked Word: t _ _ r _ t _ _ s Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: t _ _ r i t _ _ s Lives: 3
# Guessing letter: l
# Status: Guess incorrect Masked Word: t _ _ r i t _ _ s Lives: 2
# Guessing letter: u
# Status: Guess incorrect Masked Word: t _ _ r i t _ _ s Lives: 1
# Guessing letter: a
# Status: Guess correct Masked Word: t _ a r i t _ a s Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: t _ a r i t _ a s Lives: 0
# Game 33 failed.
#
# New game started! Game ID: 34
# Lives: 6
# Word: t l a
# Masked: _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ Lives: 6
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ _ Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: t _ _ Lives: 2
# Guessing letter: l
# Status: Guess correct Masked Word: t l _ Lives: 2
# Guessing letter: a
# Status: Guess correct Masked Word: t l a Lives: 2
# Game 34 success!
#
# New game started! Game ID: 35
# Lives: 6
# Word: t a b l e t o p p e d
# Masked: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ t _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ t _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: t _ _ _ e t _ _ _ e _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ _ e t _ _ _ e _ Lives: 4
# Guessing letter: a
# Status: Guess correct Masked Word: t a _ _ e t _ _ _ e _ Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: t a _ _ e t _ _ _ e _ Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: t a _ _ e t _ _ _ e _ Lives: 2
# Guessing letter: s
# Status: Guess incorrect Masked Word: t a _ _ e t _ _ _ e _ Lives: 1
# Guessing letter: l
# Status: Guess correct Masked Word: t a _ l e t _ _ _ e _ Lives: 1
# Guessing letter: o
# Status: Guess correct Masked Word: t a _ l e t o _ _ e _ Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: t a _ l e t o _ _ e _ Lives: 0
# Game 35 failed.
#
# New game started! Game ID: 36
# Lives: 6
# Word: t u r j a i t e
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ t _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ r _ _ _ t _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t _ r _ _ _ t e Lives: 6
# Guessing letter: o
# Status: Guess incorrect Masked Word: t _ r _ _ _ t e Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ r _ _ _ t e Lives: 4
# Guessing letter: u
# Status: Guess correct Masked Word: t u r _ _ _ t e Lives: 4
# Guessing letter: i
# Status: Guess correct Masked Word: t u r _ _ i t e Lives: 4
# Guessing letter: a
# Status: Guess correct Masked Word: t u r _ a i t e Lives: 4
# Guessing letter: h
# Status: Guess incorrect Masked Word: t u r _ a i t e Lives: 3
# Guessing letter: p
# Status: Guess incorrect Masked Word: t u r _ a i t e Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: t u r _ a i t e Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: t u r _ a i t e Lives: 0
# Game 36 failed.
#
# New game started! Game ID: 37
# Lives: 6
# Word: s u n d r y m e n
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess correct Masked Word: _ _ _ _ r _ _ _ _ Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ r _ _ _ _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ r _ _ e _ Lives: 3
# Guessing letter: s
# Status: Guess correct Masked Word: s _ _ _ r _ _ e _ Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: s _ _ _ r _ _ e _ Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: s _ _ _ r _ _ e _ Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: s _ _ _ r _ _ e _ Lives: 0
# Game 37 failed.
#
# New game started! Game ID: 38
# Lives: 6
# Word: t e l e u t o
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ t _ Lives: 6
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ _ _ _ t _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ _ _ t _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ t _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: t e _ e _ t _ Lives: 3
# Guessing letter: m
# Status: Guess incorrect Masked Word: t e _ e _ t _ Lives: 2
# Guessing letter: i
# Status: Guess incorrect Masked Word: t e _ e _ t _ Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: t e _ e _ t _ Lives: 0
# Game 38 failed.
#
# New game started! Game ID: 39
# Lives: 6
# Word: t a l l o w e r
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ _ _ _ _ r Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t _ _ _ _ _ e r Lives: 6
# Guessing letter: i
# Status: Guess incorrect Masked Word: t _ _ _ _ _ e r Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ _ _ _ _ e r Lives: 4
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ _ _ _ _ e r Lives: 3
# Guessing letter: a
# Status: Guess correct Masked Word: t a _ _ _ _ e r Lives: 3
# Guessing letter: s
# Status: Guess incorrect Masked Word: t a _ _ _ _ e r Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: t a _ _ _ _ e r Lives: 1
# Guessing letter: o
# Status: Guess correct Masked Word: t a _ _ o _ e r Lives: 1
# Guessing letter: d
# Status: Guess incorrect Masked Word: t a _ _ o _ e r Lives: 0
# Game 39 failed.
#
# New game started! Game ID: 40
# Lives: 6
# Word: s u s a n o o
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ a _ _ _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ a n _ _ Lives: 5
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ a n _ _ Lives: 4
# Guessing letter: l
# Status: Guess incorrect Masked Word: _ _ _ a n _ _ Lives: 3
# Guessing letter: e
# Status: Guess incorrect Masked Word: _ _ _ a n _ _ Lives: 2
# Guessing letter: o
# Status: Guess correct Masked Word: _ _ _ a n o o Lives: 2
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ _ a n o o Lives: 1
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ a n o o Lives: 0
# Game 40 failed.
#
# New game started! Game ID: 41
# Lives: 6
# Word: s p u n k i n g
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ Lives: 3
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ n _ _ n _ Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ _ n _ i n _ Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ n _ i n _ Lives: 2
# Guessing letter: s
# Status: Guess correct Masked Word: s _ _ n _ i n _ Lives: 2
# Guessing letter: o
# Status: Guess incorrect Masked Word: s _ _ n _ i n _ Lives: 1
# Guessing letter: p
# Status: Guess correct Masked Word: s p _ n _ i n _ Lives: 1
# Guessing letter: e
# Status: Guess incorrect Masked Word: s p _ n _ i n _ Lives: 0
# Game 41 failed.
#
# New game started! Game ID: 42
# Lives: 6
# Word: t o m b e
# Masked: _ _ _ _ _
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: _ _ _ _ _ Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ e Lives: 3
# Guessing letter: o
# Status: Guess correct Masked Word: _ o _ _ e Lives: 3
# Guessing letter: l
# Status: Guess incorrect Masked Word: _ o _ _ e Lives: 2
# Guessing letter: m
# Status: Guess correct Masked Word: _ o m _ e Lives: 2
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ o m _ e Lives: 1
# Guessing letter: d
# Status: Guess incorrect Masked Word: _ o m _ e Lives: 0
# Game 42 failed.
#
# New game started! Game ID: 43
# Lives: 6
# Word: s t a r r y b r i g h t
# Masked: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ _ _ _ _ t Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: _ t a _ _ _ _ _ _ _ _ t Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ t a _ _ _ _ _ _ _ _ t Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: _ t a _ _ _ _ _ i _ _ t Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ t a _ _ _ _ _ i _ _ t Lives: 4
# Guessing letter: s
# Status: Guess correct Masked Word: s t a _ _ _ _ _ i _ _ t Lives: 4
# Guessing letter: l
# Status: Guess incorrect Masked Word: s t a _ _ _ _ _ i _ _ t Lives: 3
# Guessing letter: m
# Status: Guess incorrect Masked Word: s t a _ _ _ _ _ i _ _ t Lives: 2
# Guessing letter: o
# Status: Guess incorrect Masked Word: s t a _ _ _ _ _ i _ _ t Lives: 1
# Guessing letter: r
# Status: Guess correct Masked Word: s t a r r _ _ r i _ _ t Lives: 1
# Guessing letter: e
# Status: Guess incorrect Masked Word: s t a r r _ _ r i _ _ t Lives: 0
# Game 43 failed.
#
# New game started! Game ID: 44
# Lives: 6
# Word: t r a i n m i l e
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t r _ _ _ _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t r _ _ _ _ _ _ e Lives: 6
# Guessing letter: i
# Status: Guess correct Masked Word: t r _ i _ _ i _ e Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t r _ i n _ i _ e Lives: 6
# Guessing letter: c
# Status: Guess incorrect Masked Word: t r _ i n _ i _ e Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: t r _ i n _ i _ e Lives: 4
# Guessing letter: b
# Status: Guess incorrect Masked Word: t r _ i n _ i _ e Lives: 3
# Guessing letter: p
# Status: Guess incorrect Masked Word: t r _ i n _ i _ e Lives: 2
# Guessing letter: m
# Status: Guess correct Masked Word: t r _ i n m i _ e Lives: 2
# Guessing letter: f
# Status: Guess incorrect Masked Word: t r _ i n m i _ e Lives: 1
# Guessing letter: d
# Status: Guess incorrect Masked Word: t r _ i n m i _ e Lives: 0
# Game 44 failed.
#
# New game started! Game ID: 45
# Lives: 6
# Word: s p o n g i i d a e
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ _ a _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ n _ _ _ _ a _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ _ n _ i i _ a _ Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ n _ i i _ a _ Lives: 4
# Guessing letter: s
# Status: Guess correct Masked Word: s _ _ n _ i i _ a _ Lives: 4
# Guessing letter: m
# Status: Guess incorrect Masked Word: s _ _ n _ i i _ a _ Lives: 3
# Guessing letter: o
# Status: Guess correct Masked Word: s _ o n _ i i _ a _ Lives: 3
# Guessing letter: p
# Status: Guess correct Masked Word: s p o n _ i i _ a _ Lives: 3
# Guessing letter: l
# Status: Guess incorrect Masked Word: s p o n _ i i _ a _ Lives: 2
# Guessing letter: h
# Status: Guess incorrect Masked Word: s p o n _ i i _ a _ Lives: 1
# Guessing letter: r
# Status: Guess incorrect Masked Word: s p o n _ i i _ a _ Lives: 0
# Game 45 failed.
#
# New game started! Game ID: 46
# Lives: 6
# Word: s y n c a r p i e s
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ _ a _ _ _ _ _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ n _ a _ _ _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ n _ a _ _ i _ _ Lives: 5
# Guessing letter: p
# Status: Guess correct Masked Word: _ _ n _ a _ p i _ _ Lives: 5
# Guessing letter: c
# Status: Guess correct Masked Word: _ _ n c a _ p i _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ n c a _ p i e _ Lives: 5
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ n c a _ p i e _ Lives: 4
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ n c a _ p i e _ Lives: 3
# Guessing letter: u
# Status: Guess incorrect Masked Word: _ _ n c a _ p i e _ Lives: 2
# Guessing letter: s
# Status: Guess correct Masked Word: s _ n c a _ p i e s Lives: 2
# Guessing letter: h
# Status: Guess incorrect Masked Word: s _ n c a _ p i e s Lives: 1
# Guessing letter: y
# Status: Guess correct Masked Word: s y n c a _ p i e s Lives: 1
# Guessing letter: l
# Status: Guess incorrect Masked Word: s y n c a _ p i e s Lives: 0
# Game 46 failed.
#
# New game started! Game ID: 47
# Lives: 6
# Word: t r a n s i t e d
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ t _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t r _ _ _ _ t _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t r _ _ _ _ t e _ Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t r _ n _ _ t e _ Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: t r a n _ _ t e _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: t r a n s _ t e _ Lives: 6
# Guessing letter: i
# Status: Guess correct Masked Word: t r a n s i t e _ Lives: 6
# Guessing letter: c
# Status: Guess incorrect Masked Word: t r a n s i t e _ Lives: 5
# Guessing letter: d
# ...
# Status: Guess correct Masked Word: _ _ n c a t e _ o r e _ Lives: 4
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ n c a t e _ o r e _ Lives: 3
# Guessing letter: s
# Status: Guess correct Masked Word: s _ n c a t e _ o r e _ Lives: 3
# Guessing letter: m
# Status: Guess correct Masked Word: s _ n c a t e _ o r e m Lives: 3
# Guessing letter: u
# Status: Guess incorrect Masked Word: s _ n c a t e _ o r e m Lives: 2
# Guessing letter: d
# Status: Guess incorrect Masked Word: s _ n c a t e _ o r e m Lives: 1
# Guessing letter: b
# Status: Guess incorrect Masked Word: s _ n c a t e _ o r e m Lives: 0
# Game 85 failed.
#
# New game started! Game ID: 86
# Lives: 6
# Word: s w i h a r t
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ _ _ _ _ _ t Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: _ _ _ _ _ r t Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ _ _ _ r t Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: _ _ _ _ _ r t Lives: 4
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ _ _ _ r t Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ _ _ r t Lives: 2
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ _ _ _ r t Lives: 1
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ _ _ a r t Lives: 1
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ i _ a r t Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ i _ a r t Lives: 0
# Game 86 failed.
#
# New game started! Game ID: 87
# Lives: 6
# Word: t i n k e r e d
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ _ _ _ r _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t _ _ _ e r e _ Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t _ n _ e r e _ Lives: 6
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ n _ e r e _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ n _ e r e _ Lives: 4
# Guessing letter: m
# Status: Guess incorrect Masked Word: t _ n _ e r e _ Lives: 3
# Guessing letter: i
# Status: Guess correct Masked Word: t i n _ e r e _ Lives: 3
# Guessing letter: d
# Status: Guess correct Masked Word: t i n _ e r e d Lives: 3
# Guessing letter: b
# Status: Guess incorrect Masked Word: t i n _ e r e d Lives: 2
# Guessing letter: g
# Status: Guess incorrect Masked Word: t i n _ e r e d Lives: 1
# Guessing letter: f
# Status: Guess incorrect Masked Word: t i n _ e r e d Lives: 0
# Game 87 failed.
#
# New game started! Game ID: 88
# Lives: 6
# Word: t h a n e h o o d
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: t _ _ _ e _ _ _ _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: t _ _ n e _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess correct Masked Word: t _ a n e _ _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess incorrect Masked Word: t _ a n e _ _ _ _ Lives: 4
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ a n e _ _ _ _ Lives: 3
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ a n e _ _ _ _ Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: t _ a n e _ _ _ _ Lives: 1
# Guessing letter: o
# Status: Guess correct Masked Word: t _ a n e _ o o _ Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: t _ a n e _ o o _ Lives: 0
# Game 88 failed.
#
# New game started! Game ID: 89
# Lives: 6
# Word: t r a n s m u t a t i o n i s t
# Masked: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ t _ t _ _ _ _ _ t Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t r _ _ _ _ _ t _ t _ _ _ _ _ t Lives: 6
# Guessing letter: n
# Status: Guess correct Masked Word: t r _ n _ _ _ t _ t _ _ n _ _ t Lives: 6
# Guessing letter: i
# Status: Guess correct Masked Word: t r _ n _ _ _ t _ t i _ n i _ t Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: t r a n _ _ _ t a t i _ n i _ t Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: t r a n s _ _ t a t i _ n i s t Lives: 6
# Guessing letter: c
# Status: Guess incorrect Masked Word: t r a n s _ _ t a t i _ n i s t Lives: 5
# Guessing letter: l
# Status: Guess incorrect Masked Word: t r a n s _ _ t a t i _ n i s t Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t r a n s _ _ t a t i o n i s t Lives: 4
# Guessing letter: e
# Status: Guess incorrect Masked Word: t r a n s _ _ t a t i o n i s t Lives: 3
# Guessing letter: h
# Status: Guess incorrect Masked Word: t r a n s _ _ t a t i o n i s t Lives: 2
# Guessing letter: u
# Status: Guess correct Masked Word: t r a n s _ u t a t i o n i s t Lives: 2
# Guessing letter: f
# Status: Guess incorrect Masked Word: t r a n s _ u t a t i o n i s t Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: t r a n s _ u t a t i o n i s t Lives: 0
# Game 89 failed.
#
# New game started! Game ID: 90
# Lives: 6
# Word: t e n d a n c e
# Masked: _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: t e _ _ _ _ _ e Lives: 5
# Guessing letter: i
# Status: Guess incorrect Masked Word: t e _ _ _ _ _ e Lives: 4
# Guessing letter: n
# Status: Guess correct Masked Word: t e n _ _ n _ e Lives: 4
# Guessing letter: s
# Status: Guess incorrect Masked Word: t e n _ _ n _ e Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: t e n _ _ n _ e Lives: 2
# Guessing letter: a
# Status: Guess correct Masked Word: t e n _ a n _ e Lives: 2
# Guessing letter: c
# Status: Guess correct Masked Word: t e n _ a n c e Lives: 2
# Guessing letter: p
# Status: Guess incorrect Masked Word: t e n _ a n c e Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: t e n _ a n c e Lives: 0
# Game 90 failed.
#
# New game started! Game ID: 91
# Lives: 6
# Word: t r u t h l i k e
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ t _ _ _ _ _ Lives: 6
# Guessing letter: a
# Status: Guess incorrect Masked Word: t _ _ t _ _ _ _ _ Lives: 5
# Guessing letter: r
# Status: Guess correct Masked Word: t r _ t _ _ _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: t r _ t _ _ i _ _ Lives: 5
# Guessing letter: n
# Status: Guess incorrect Masked Word: t r _ t _ _ i _ _ Lives: 4
# Guessing letter: s
# Status: Guess incorrect Masked Word: t r _ t _ _ i _ _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: t r _ t _ _ i _ e Lives: 3
# Guessing letter: o
# Status: Guess incorrect Masked Word: t r _ t _ _ i _ e Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: t r _ t _ _ i _ e Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: t r _ t _ _ i _ e Lives: 0
# Game 91 failed.
#
# New game started! Game ID: 92
# Lives: 6
# Word: t h o r e z
# Masked: _ _ _ _ _ _
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 4
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ Lives: 3
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ _ e _ Lives: 3
# Guessing letter: r
# Status: Guess correct Masked Word: _ _ _ r e _ Lives: 3
# Guessing letter: d
# Status: Guess incorrect Masked Word: _ _ _ r e _ Lives: 2
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ r e _ Lives: 1
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ _ r e _ Lives: 0
# Game 92 failed.
#
# New game started! Game ID: 93
# Lives: 6
# Word: t r i o l e f i n
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t r _ _ _ _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t r _ _ _ e _ _ _ Lives: 6
# Guessing letter: m
# Status: Guess incorrect Masked Word: t r _ _ _ e _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: t r i _ _ e _ i _ Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: t r i _ _ e _ i _ Lives: 4
# Guessing letter: p
# Status: Guess incorrect Masked Word: t r i _ _ e _ i _ Lives: 3
# Guessing letter: s
# Status: Guess incorrect Masked Word: t r i _ _ e _ i _ Lives: 2
# Guessing letter: n
# Status: Guess correct Masked Word: t r i _ _ e _ i n Lives: 2
# Guessing letter: d
# Status: Guess incorrect Masked Word: t r i _ _ e _ i n Lives: 1
# Guessing letter: a
# Status: Guess incorrect Masked Word: t r i _ _ e _ i n Lives: 0
# Game 93 failed.
#
# New game started! Game ID: 94
# Lives: 6
# Word: s t o r e h o u s e s
# Masked: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ t _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: s
# Status: Guess correct Masked Word: s t _ _ _ _ _ _ s _ s Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: s t _ _ e _ _ _ s e s Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: s t _ r e _ _ _ s e s Lives: 6
# Guessing letter: o
# Status: Guess correct Masked Word: s t o r e _ o _ s e s Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: s t o r e _ o _ s e s Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: s t o r e _ o _ s e s Lives: 4
# Guessing letter: d
# Status: Guess incorrect Masked Word: s t o r e _ o _ s e s Lives: 3
# Guessing letter: u
# Status: Guess correct Masked Word: s t o r e _ o u s e s Lives: 3
# Guessing letter: f
# Status: Guess incorrect Masked Word: s t o r e _ o u s e s Lives: 2
# Guessing letter: b
# Status: Guess incorrect Masked Word: s t o r e _ o u s e s Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: s t o r e _ o u s e s Lives: 0
# Game 94 failed.
#
# New game started! Game ID: 95
# Lives: 6
# Word: t i r e d
# Masked: _ _ _ _ _
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ Lives: 5
# Guessing letter: s
# Status: Guess incorrect Masked Word: _ _ _ _ _ Lives: 4
# Guessing letter: i
# Status: Guess correct Masked Word: _ i _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ i _ _ _ Lives: 3
# Guessing letter: b
# Status: Guess incorrect Masked Word: _ i _ _ _ Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ i _ _ _ Lives: 1
# Guessing letter: r
# Status: Guess correct Masked Word: _ i r _ _ Lives: 1
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ i r _ _ Lives: 0
# Game 95 failed.
#
# New game started! Game ID: 96
# Lives: 6
# Word: s w a n w h i t e
# Masked: _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ t _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ t _ Lives: 5
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ n _ _ _ t _ Lives: 5
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ n _ _ _ t e Lives: 5
# Guessing letter: o
# Status: Guess incorrect Masked Word: _ _ _ n _ _ _ t e Lives: 4
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ _ n _ _ _ t e Lives: 3
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ _ n _ _ _ t e Lives: 2
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ _ n _ _ i t e Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: _ _ _ n _ _ i t e Lives: 1
# Guessing letter: u
# Status: Guess incorrect Masked Word: _ _ _ n _ _ i t e Lives: 0
# Game 96 failed.
#
# New game started! Game ID: 97
# Lives: 6
# Word: s w a l l o w t a i l s
# Masked: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: _ _ _ _ _ _ _ t _ _ _ _ Lives: 6
# Guessing letter: a
# Status: Guess correct Masked Word: _ _ a _ _ _ _ t a _ _ _ Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: _ _ a _ _ _ _ t a _ _ _ Lives: 5
# Guessing letter: i
# Status: Guess correct Masked Word: _ _ a _ _ _ _ t a i _ _ Lives: 5
# Guessing letter: l
# Status: Guess correct Masked Word: _ _ a l l _ _ t a i l _ Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: _ _ a l l _ _ t a i l _ Lives: 4
# Guessing letter: c
# Status: Guess incorrect Masked Word: _ _ a l l _ _ t a i l _ Lives: 3
# Guessing letter: p
# Status: Guess incorrect Masked Word: _ _ a l l _ _ t a i l _ Lives: 2
# Guessing letter: s
# Status: Guess correct Masked Word: s _ a l l _ _ t a i l s Lives: 2
# Guessing letter: o
# Status: Guess correct Masked Word: s _ a l l o _ t a i l s Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: s _ a l l o _ t a i l s Lives: 1
# Guessing letter: u
# Status: Guess incorrect Masked Word: s _ a l l o _ t a i l s Lives: 0
# Game 97 failed.
#
# New game started! Game ID: 98
# Lives: 6
# Word: t o r y i z e
# Masked: _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess correct Masked Word: t _ r _ _ _ _ Lives: 6
# Guessing letter: e
# Status: Guess correct Masked Word: t _ r _ _ _ e Lives: 6
# Guessing letter: i
# Status: Guess correct Masked Word: t _ r _ i _ e Lives: 6
# Guessing letter: n
# Status: Guess incorrect Masked Word: t _ r _ i _ e Lives: 5
# Guessing letter: c
# Status: Guess incorrect Masked Word: t _ r _ i _ e Lives: 4
# Guessing letter: a
# Status: Guess incorrect Masked Word: t _ r _ i _ e Lives: 3
# Guessing letter: p
# Status: Guess incorrect Masked Word: t _ r _ i _ e Lives: 2
# Guessing letter: o
# Status: Guess correct Masked Word: t o r _ i _ e Lives: 2
# Guessing letter: d
# Status: Guess incorrect Masked Word: t o r _ i _ e Lives: 1
# Guessing letter: m
# Status: Guess incorrect Masked Word: t o r _ i _ e Lives: 0
# Game 98 failed.
#
# New game started! Game ID: 99
# Lives: 6
# Word: s p o n g o c o e l
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: a
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: r
# Status: Guess incorrect Masked Word: _ _ _ _ _ _ _ _ _ _ Lives: 3
# Guessing letter: n
# Status: Guess correct Masked Word: _ _ _ n _ _ _ _ _ _ Lives: 3
# Guessing letter: i
# Status: Guess incorrect Masked Word: _ _ _ n _ _ _ _ _ _ Lives: 2
# Guessing letter: e
# Status: Guess correct Masked Word: _ _ _ n _ _ _ _ e _ Lives: 2
# Guessing letter: o
# Status: Guess correct Masked Word: _ _ o n _ o _ o e _ Lives: 2
# Guessing letter: c
# Status: Guess correct Masked Word: _ _ o n _ o c o e _ Lives: 2
# Guessing letter: s
# Status: Guess correct Masked Word: s _ o n _ o c o e _ Lives: 2
# Guessing letter: m
# Status: Guess incorrect Masked Word: s _ o n _ o c o e _ Lives: 1
# Guessing letter: p
# Status: Guess correct Masked Word: s p o n _ o c o e _ Lives: 1
# Guessing letter: l
# Status: Guess correct Masked Word: s p o n _ o c o e l Lives: 1
# Guessing letter: h
# Status: Guess incorrect Masked Word: s p o n _ o c o e l Lives: 0
# Game 99 failed.
#
# New game started! Game ID: 100
# Lives: 6
# Word: t i b o u c h i n a
# Masked: _ _ _ _ _ _ _ _ _ _
# Guessing letter: t
# Status: Guess correct Masked Word: t _ _ _ _ _ _ _ _ _ Lives: 6
# Guessing letter: r
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ _ _ Lives: 5
# Guessing letter: e
# Status: Guess incorrect Masked Word: t _ _ _ _ _ _ _ _ _ Lives: 4
# Guessing letter: o
# Status: Guess correct Masked Word: t _ _ o _ _ _ _ _ _ Lives: 4
# Guessing letter: n
# Status: Guess correct Masked Word: t _ _ o _ _ _ _ n _ Lives: 4
# Guessing letter: c
# Status: Guess correct Masked Word: t _ _ o _ c _ _ n _ Lives: 4
# Guessing letter: s
# Status: Guess incorrect Masked Word: t _ _ o _ c _ _ n _ Lives: 3
# Guessing letter: m
# Status: Guess incorrect Masked Word: t _ _ o _ c _ _ n _ Lives: 2
# Guessing letter: i
# Status: Guess correct Masked Word: t i _ o _ c _ i n _ Lives: 2
# Guessing letter: p
# Status: Guess incorrect Masked Word: t i _ o _ c _ i n _ Lives: 1
# Guessing letter: a
# Status: Guess correct Masked Word: t i _ o _ c _ i n a Lives: 1
# Guessing letter: h
# Status: Guess correct Masked Word: t i _ o _ c h i n a Lives: 1
# Guessing letter: l
# Status: Guess incorrect Masked Word: t i _ o _ c h i n a Lives: 0
# Game 100 failed.
#
#
# Success rate: 21/100 games
